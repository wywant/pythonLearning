# %%
# https://docs.python.org/3/library/inspect.html
import inspect
import tensorflow.keras.layers as layers

# %%
#ls.append(layers.Layer)
#ls.append(layers.Flatten)
#ls.append(layers.Dense)
#ls.append(layers.Conv1D)
#ls.append(layers.Conv2D)
#ls.append(layers.Conv3D)
#ls.append(layers.ReLU)
#ls.append(layers.RNN)
#ls.append(layers.LSTM)

names = dir(layers)
classesInPackage = []
for name in names:
    attr = getattr(layers, name)
    if inspect.isclass(attr):
        #print(attr)
        classesInPackage.append(attr)
        #print(name)
layerSubClasses = []
for classInPackage in classesInPackage:
    if classInPackage.__base__ == layers.Layer:
        layerSubClasses.append(classInPackage)
        print(classInPackage)


cs = []
cnames = []
for alayer in layerSubClasses:
    cnames.append(alayer.__name__)
    cs.append(inspect.signature(alayer.__init__))
    
arguments = []
signatureArguments = []
for signature in cs:
    args = []
    for k in signature.parameters:
        if k == 'self':
            continue;
        if k == 'kwargs':
            continue;
        if k not in arguments:
            arguments.append(k)
        args.append(k)
    print(args)
    signatureArguments.append(args)

#print(cnames)             
lines = []
for k in arguments:
#    print(k)
    line = []
    line.append(k)
    for signatureArgument in signatureArguments:
        if k in signatureArgument:
            line.append('Y')
        else :
            line.append('')
    lines.append(line)
    print(','.join(line))

#    print(line)
with open('layers.csv', 'wt') as f:
    f.write(',')
    f.write(','.join(cnames))
    f.write('\n')
    for line in lines:
        f.write(','.join(line))
        f.write('\n')
    
        
#    print(k)
#    print(type(k))
#print(signature)
#print(signature.parameters)
#print(signature.args)
# Out:
# ['trainable', 'name', 'dtype']
# ['data_format']
# ['units', 'activation', 'use_bias', 'kernel_initializer', 'bias_initializer', 'kernel_regularizer', 'bias_regularizer', 'activity_regularizer', 'kernel_constraint', 'bias_constraint']
# ['cell', 'return_sequences', 'return_state', 'go_backwards', 'stateful', 'unroll']
# ['units', 'activation', 'recurrent_activation', 'use_bias', 'kernel_initializer', 'recurrent_initializer', 'bias_initializer', 'unit_forget_bias', 'kernel_regularizer', 'recurrent_regularizer', 'bias_regularizer', 'activity_regularizer', 'kernel_constraint', 'recurrent_constraint', 'bias_constraint', 'dropout', 'recurrent_dropout', 'implementation', 'return_sequences', 'return_state', 'go_backwards', 'stateful', 'unroll']
# trainable,Y,,,,
# name,Y,,,,
# dtype,Y,,,,
# data_format,,Y,,,
# units,,,Y,,Y
# activation,,,Y,,Y
# use_bias,,,Y,,Y
# kernel_initializer,,,Y,,Y
# bias_initializer,,,Y,,Y
# kernel_regularizer,,,Y,,Y
# bias_regularizer,,,Y,,Y
# activity_regularizer,,,Y,,Y
# kernel_constraint,,,Y,,Y
# bias_constraint,,,Y,,Y
# cell,,,,Y,
# return_sequences,,,,Y,Y
# return_state,,,,Y,Y
# go_backwards,,,,Y,Y
# stateful,,,,Y,Y
# unroll,,,,Y,Y
# recurrent_activation,,,,,Y
# recurrent_initializer,,,,,Y
# unit_forget_bias,,,,,Y
# recurrent_regularizer,,,,,Y
# recurrent_constraint,,,,,Y
# dropout,,,,,Y
# recurrent_dropout,,,,,Y
# implementation,,,,,Y
